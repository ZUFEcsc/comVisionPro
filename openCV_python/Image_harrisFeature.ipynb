# %% [markdown]
# # 图像特征-harris角点检测

# %% [markdown]
# ![title](ImgFeature/harris1.png)
# ![title](ImgFeature/harris2.png)
# ![title](ImgFeature/harris3.png)
# ![title](ImgFeature/harris4.png)
# ![title](ImgFeature/harris5.png)
# ![title](ImgFeature/harris6.png)
# ![title](ImgFeature/harris7.png)
# ![title](ImgFeature/harris8.png)

# %%
import cv2  #opencv 读取进来为BGR格式
import matplotlib.pyplot as plt
import numpy as np

#一个魔法指令，不需要采用plt.show()显示图像
# %matplotlib inline

# %%
def cv_show(name,img):
    cv2.imshow(name,img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %% [markdown]
# ### cv2.cornerHarris()
# - img - 输入图像，应为灰度和float32类型。
# - blockSize - 角点检测中指定区域的大小
# - ksize - Sobel求导中使用的窗口大小
# - k - 取值参数为[0.04,0.06]

# %%
img = cv2.imread('mycat.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)

print('img.shape:',img.shape)
dst = cv2.cornerHarris(gray,2,3,0.04)
#result用于标记角点，并不重要
dst = cv2.dilate(dst,None)
print('dst.shape:',dst.shape)
# Out:
# img.shape: (413, 550, 3)
# dst.shape: (413, 550)

# %%
#最佳值的阈值，它可能因图像而异。
img[dst>0.01*dst.max()]=[0,0,255]
#cv_show('dst',img)
plt.imshow(img)
plt.show()
